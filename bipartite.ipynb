# %%
# %matplotlib inline
import networkx as nx
import numpy as np
import pandas as pd
# import projx as px
import matplotlib.pyplot as plt
import seaborn as sns

# %%
g = nx.read_gexf('projections/bipartite.gexf')

# %%
# g.nodes(data=True)

# %%
g.node['428']
# Out:
# {'doc_type': u"{u'Aprobacion': 13}",
#  'fecha': u"{'': 1, '1611-03-29': 1, '1614-12-11': 1, '1614-09-16': 1, '1617-07-24': 1, '1615-11-05': 1, '1616-12-19': 1, '1612-12-30': 1, '1614-10-03': 1, '1617-09-24': 1, '1609-08-01': 1, '1612-07-09': 1, '1617-05-16': 1}",
#  'genero': u"{'Teatro': 8, 'Ficcion': 14, 'Poesia': 3}",
#  'inst': u"{u'Consejo de Castilla': 1}",
#  'label': 'Gutierre de Cetina, Vicario General',
#  'lugar': u"{'': 1, u'Madrid': 12}",
#  'real': u"{'True': 1}",
#  'role': u'signatory',
#  'type': u'Persona'}

# %%
len(g.edge['800'])
# Out:
# 37

# %%
len(g.edge['428'])
# Out:
# 25

# %%
g.degree()
# Out:
# {'1': 5,
#  '10': 7,
#  '1000': 6,
#  '1002': 4,
#  '1011': 7,
#  '1014': 1,
#  '1016': 2,
#  '1017': 5,
#  '1018': 13,
#  '1020': 2,
#  '1021': 2,
#  '1028': 1,
#  '1042': 6,
#  '1044': 1,
#  '1045': 7,
#  '1046': 1,
#  '1072': 2,
#  '1073': 2,
#  '1074': 18,
#  '1079': 1,
#  '1082': 1,
#  '1083': 1,
#  '1084': 1,
#  '1097': 8,
#  '1099': 1,
#  '1100': 1,
#  '1107': 12,
#  '1111': 1,
#  '1117': 11,
#  '1118': 2,
#  '1119': 4,
#  '112': 7,
#  '1121': 2,
#  '1123': 4,
#  '1127': 6,
#  '1131': 1,
#  '1132': 1,
#  '1133': 1,
#  '1134': 1,
#  '1136': 1,
#  '1138': 5,
#  '1140': 1,
#  '1141': 1,
#  '1142': 2,
#  '1143': 1,
#  '1144': 1,
#  '1146': 2,
#  '1147': 1,
#  '1155': 2,
#  '1156': 1,
#  '1157': 4,
#  '1158': 1,
#  '1161': 1,
#  '1162': 1,
#  '1163': 1,
#  '1165': 10,
#  '1167': 1,
#  '1168': 1,
#  '1171': 6,
#  '1172': 1,
#  '1173': 6,
#  '1175': 1,
#  '1176': 2,
#  '118': 8,
#  '1180': 2,
#  '1182': 2,
#  '1186': 5,
#  '1189': 8,
#  '1192': 5,
#  '1195': 6,
#  '1196': 8,
# ...

# %%
g.node["1074"]
# Out:
# {'fecha': u"{'1616-01-01': 1}",
#  'genero': u"{'Teatro': 1}",
#  'informacion bibliografica': u"{'Flor de las comedias de Espana, de diferentes autores. Quinta parte': 1}",
#  'label': 'Comedias V Barcelona Cormellas 1616',
#  'lugar': u"{u'Barcelona': 1}",
#  'numero': u"{'Comedias V Barcelona Cormellas 1616': 1}",
#  'type': u'Edicion'}

# %%
nbunch = [n for n, a in g.nodes(data=True) if a['type'] == 'Persona']

# %%
g.degree(nbunch=nbunch)
# Out:
# {'10': 7,
#  '1000': 6,
#  '1002': 4,
#  '1014': 1,
#  '1016': 2,
#  '1020': 2,
#  '1021': 2,
#  '1028': 1,
#  '1044': 1,
#  '1046': 1,
#  '1072': 2,
#  '1073': 2,
#  '1079': 1,
#  '1082': 1,
#  '1083': 1,
#  '1084': 1,
#  '1099': 1,
#  '1100': 1,
#  '1111': 1,
#  '1118': 2,
#  '1131': 1,
#  '1132': 1,
#  '1133': 1,
#  '1134': 1,
#  '1136': 1,
#  '1140': 1,
#  '1141': 1,
#  '1142': 2,
#  '1143': 1,
#  '1144': 1,
#  '1146': 2,
#  '1147': 1,
#  '1155': 2,
#  '1156': 1,
#  '1157': 4,
#  '1158': 1,
#  '1161': 1,
#  '1162': 1,
#  '1163': 1,
#  '1167': 1,
#  '1168': 1,
#  '1172': 1,
#  '1175': 1,
#  '1176': 2,
#  '1180': 2,
#  '1182': 2,
#  '1186': 5,
#  '1192': 5,
#  '1197': 1,
#  '1198': 15,
#  '1208': 1,
#  '1209': 1,
#  '121': 1,
#  '1212': 3,
#  '1213': 3,
#  '1215': 3,
#  '1216': 3,
#  '122': 1,
#  '1223': 2,
#  '1224': 1,
#  '1225': 1,
#  '1229': 1,
#  '1234': 1,
#  '1237': 1,
#  '1253': 2,
#  '1254': 2,
#  '1266': 10,
#  '1267': 1,
#  '1289': 4,
#  '1291': 4,
#  '1294': 2,
# ...
